# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
df=pd.read_csv('sales_data_with_discounts.csv')
df.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %% [markdown]
# - we can see here that data is perfectly clean
# - there are 6 columns with Numeric data type

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495427     47847.912852
# ...

# %% [markdown]
# - here we can see that <b>Volume and Discount Rate</b> have almost same mean and median we can say that these columns are evenly spread out with little variation or outliers.
# - <b>Avg price, Total sales value, Discount amount and Net sales value columns</b> have very large diffrence in their mean and median we can see that there std dev is also very large
# - A high standard deviation means data points are spread out over a wider range of values, far from the average (mean), indicating high variability, volatility, or uncertainty

# %%
sns.histplot(df['Volume'], kde=True)
# Out:
# <Axes: xlabel='Volume', ylabel='Count'>

# %% [markdown]
# ### from this histogram we can say that there are some outliers present in this column. outliers are those whose value is above 20

# %%
sns.histplot(df['Avg Price'], kde=True)
# Out:
# <Axes: xlabel='Avg Price', ylabel='Count'>

# %%
sns.boxplot(df['Avg Price'])
# Out:
# <Axes: ylabel='Avg Price'>

# %% [markdown]
# ### with this boxplot of the Avg price we can say there are outliers in this data .
# - we can see that the max value is around 20000-25000
# - min value is around zero and also the median is around zero
# - most of the data lie around 0-10000

# %%
sns.boxplot(df['Total Sales Value'])
# Out:
# <Axes: ylabel='Total Sales Value'>

# %% [markdown]
# ### as we can see total sales value is also not evenly distributed there are some outliers
# - max value is around 125000
# - min value is around 0
# - most of the data lie around 0-55000
# - and there is large diff in mean and median
